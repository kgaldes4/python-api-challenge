# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | portland
# Processing Record 5 of Set 1 | gizo
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | klyuchi
# Processing Record 8 of Set 1 | emerald
# Processing Record 9 of Set 1 | lautoka
# Processing Record 10 of Set 1 | grand baie
# Processing Record 11 of Set 1 | chonchi
# Processing Record 12 of Set 1 | la passe
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | puerto natales
# Processing Record 16 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | gadzhiyevo
# Processing Record 19 of Set 1 | stanley
# Processing Record 20 of Set 1 | buka
# Processing Record 21 of Set 1 | whitby
# Processing Record 22 of Set 1 | badger
# Processing Record 23 of Set 1 | olonkinbyen
# Processing Record 24 of Set 1 | nagqu
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | papatowai
# Processing Record 27 of Set 1 | qamdo
# Processing Record 28 of Set 1 | menaka
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | vadso
# Processing Record 31 of Set 1 | howrah
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | kovdor
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | tommot
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | lihue
# Processing Record 38 of Set 1 | qaqortoq
# Processing Record 39 of Set 1 | sonsorol village
# City not found. Skipping...
# Processing Record 40 of Set 1 | banda aceh
# Processing Record 41 of Set 1 | berezovyy
# Processing Record 42 of Set 1 | serang
# Processing Record 43 of Set 1 | bikenibeu village
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | illizi
# Processing Record 46 of Set 1 | miyanoura
# City not found. Skipping...
# Processing Record 47 of Set 1 | edinburgh of the seven seas
# Processing Record 48 of Set 1 | tual
# Processing Record 49 of Set 1 | belle glade
# Processing Record 50 of Set 1 | seven pagodas
# Processing Record 0 of Set 2 | palopo
# Processing Record 1 of Set 2 | isafjordur
# Processing Record 2 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | kourou
# Processing Record 5 of Set 2 | nova sintra
# Processing Record 6 of Set 2 | iskateley
# Processing Record 7 of Set 2 | nicoya
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | kimbe
# Processing Record 11 of Set 2 | adamstown
# Processing Record 12 of Set 2 | sangin
# Processing Record 13 of Set 2 | utrik
# Processing Record 14 of Set 2 | brisas barra de suchiate
# Processing Record 15 of Set 2 | yeppoon
# Processing Record 16 of Set 2 | siwa oasis
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | constantia
# Processing Record 19 of Set 2 | invercargill
# Processing Record 20 of Set 2 | karratha
# Processing Record 21 of Set 2 | luganville
# Processing Record 22 of Set 2 | christchurch
# Processing Record 23 of Set 2 | udachny
# Processing Record 24 of Set 2 | rabo de peixe
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | malpica
# Processing Record 27 of Set 2 | yaren
# Processing Record 28 of Set 2 | west island
# Processing Record 29 of Set 2 | palikir - national government center
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | bandar lampung
# Processing Record 32 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 2 | college
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | gjirokaster
# Processing Record 36 of Set 2 | tazovsky
# Processing Record 37 of Set 2 | bestobe
# Processing Record 38 of Set 2 | subaykhan
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | waingapu
# Processing Record 41 of Set 2 | bubaque
# Processing Record 42 of Set 2 | betioky
# Processing Record 43 of Set 2 | bandon
# Processing Record 44 of Set 2 | port mathurin
# Processing Record 45 of Set 2 | santa ana
# Processing Record 46 of Set 2 | orange walk
# Processing Record 47 of Set 2 | abbeville
# Processing Record 48 of Set 2 | sao gabriel da cachoeira
# Processing Record 49 of Set 2 | esil
# Processing Record 0 of Set 3 | sao felix do xingu
# Processing Record 1 of Set 3 | kruisfontein
# Processing Record 2 of Set 3 | aguai
# Processing Record 3 of Set 3 | bayan nur
# City not found. Skipping...
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | kidal
# Processing Record 8 of Set 3 | shahrud
# Processing Record 9 of Set 3 | xai-xai
# Processing Record 10 of Set 3 | ushuaia
# Processing Record 11 of Set 3 | usinsk
# Processing Record 12 of Set 3 | messini
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | kone
# Processing Record 15 of Set 3 | alofi
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | praya
# Processing Record 18 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 19 of Set 3 | arkhangel'sk
# Processing Record 20 of Set 3 | wailua homesteads
# Processing Record 21 of Set 3 | siocon
# Processing Record 22 of Set 3 | ulsan
# Processing Record 23 of Set 3 | vredenburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | ryotsu-minato
# Processing Record 25 of Set 3 | hibbing
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | dalandzadgad
# Processing Record 28 of Set 3 | grand falls-windsor
# Processing Record 29 of Set 3 | namibe
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | margaret river
# Processing Record 32 of Set 3 | dudinka
# Processing Record 33 of Set 3 | dhidhdhoo
# Processing Record 34 of Set 3 | san luis de la loma
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | mejit
# Processing Record 37 of Set 3 | keflavik
# Processing Record 38 of Set 3 | hawaiian paradise park
# Processing Record 39 of Set 3 | victorica
# Processing Record 40 of Set 3 | plettenberg bay
# Processing Record 41 of Set 3 | burang
# Processing Record 42 of Set 3 | markovo
# Processing Record 43 of Set 3 | jalalaqsi
# Processing Record 44 of Set 3 | pacific grove
# Processing Record 45 of Set 3 | bambari
# Processing Record 46 of Set 3 | bucerias
# Processing Record 47 of Set 3 | veymandoo
# City not found. Skipping...
# Processing Record 48 of Set 3 | jinghong
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 0 of Set 4 | mouila
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | kolonia town
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | alesund
# Processing Record 5 of Set 4 | penalva
# Processing Record 6 of Set 4 | havsa
# Processing Record 7 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 8 of Set 4 | flying fish cove
# Processing Record 9 of Set 4 | maintal
# Processing Record 10 of Set 4 | holbrook
# Processing Record 11 of Set 4 | iquique
# Processing Record 12 of Set 4 | cabinda
# Processing Record 13 of Set 4 | cesme
# Processing Record 14 of Set 4 | new plymouth
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | uturoa
# Processing Record 17 of Set 4 | uwajima
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | hutchinson
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | muravlenko
# Processing Record 22 of Set 4 | lom
# Processing Record 23 of Set 4 | afaahiti
# Processing Record 24 of Set 4 | namdrik
# Processing Record 25 of Set 4 | cabedelo
# Processing Record 26 of Set 4 | n'zeto
# Processing Record 27 of Set 4 | ampahana
# City not found. Skipping...
# Processing Record 28 of Set 4 | vorgashor
# Processing Record 29 of Set 4 | nikolayevsk-on-amure
# Processing Record 30 of Set 4 | augusto correa
# Processing Record 31 of Set 4 | margate
# Processing Record 32 of Set 4 | nsanje
# Processing Record 33 of Set 4 | kuta
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | douentza
# Processing Record 36 of Set 4 | puerto baquerizo moreno
# Processing Record 37 of Set 4 | tungipara
# Processing Record 38 of Set 4 | monte carmelo
# Processing Record 39 of Set 4 | greymouth
# Processing Record 40 of Set 4 | ola
# Processing Record 41 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 42 of Set 4 | egilsstadir
# Processing Record 43 of Set 4 | alamosa
# Processing Record 44 of Set 4 | darwin
# Processing Record 45 of Set 4 | moissala
# Processing Record 46 of Set 4 | ciudad de cuetzalan
# City not found. Skipping...
# Processing Record 47 of Set 4 | nogliki
# Processing Record 48 of Set 4 | gangolli
# Processing Record 49 of Set 4 | santa eularia des riu
# Processing Record 0 of Set 5 | pisco
# Processing Record 1 of Set 5 | tolanaro
# Processing Record 2 of Set 5 | kristiansund
# Processing Record 3 of Set 5 | scarborough
# Processing Record 4 of Set 5 | gallup
# Processing Record 5 of Set 5 | gaigeturi
# Processing Record 6 of Set 5 | ambanja
# Processing Record 7 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 5 | termas de rio hondo
# Processing Record 9 of Set 5 | san antonio de pale
# Processing Record 10 of Set 5 | rosarito
# Processing Record 11 of Set 5 | as sulayyil
# Processing Record 12 of Set 5 | susuman
# Processing Record 13 of Set 5 | eyl
# Processing Record 14 of Set 5 | antofagasta
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | acapulco de juarez
# Processing Record 17 of Set 5 | foley
# Processing Record 18 of Set 5 | berezovo
# Processing Record 19 of Set 5 | ongjin
# Processing Record 20 of Set 5 | atamanovka
# Processing Record 21 of Set 5 | castillos
# Processing Record 22 of Set 5 | milazzo
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | kerikeri
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | fortaleza
# Processing Record 27 of Set 5 | coron
# Processing Record 28 of Set 5 | manta
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | mbanza-ngungu
# Processing Record 31 of Set 5 | colonia
# Processing Record 32 of Set 5 | otjiwarongo
# Processing Record 33 of Set 5 | fada
# Processing Record 34 of Set 5 | kijang
# Processing Record 35 of Set 5 | whitehorse
# Processing Record 36 of Set 5 | praia da vitoria
# Processing Record 37 of Set 5 | saudarkrokur
# Processing Record 38 of Set 5 | crane
# Processing Record 39 of Set 5 | queenstown
# Processing Record 40 of Set 5 | nuuk
# Processing Record 41 of Set 5 | sao vicente
# Processing Record 42 of Set 5 | tindouf
# Processing Record 43 of Set 5 | rivne
# Processing Record 44 of Set 5 | rundu
# Processing Record 45 of Set 5 | mandalgovi
# Processing Record 46 of Set 5 | sungailiat
# Processing Record 47 of Set 5 | holland
# Processing Record 48 of Set 5 | saldanha
# Processing Record 49 of Set 5 | st. john's
# Processing Record 0 of Set 6 | fedorovskiy
# Processing Record 1 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 6 | badagry
# Processing Record 3 of Set 6 | lauro de freitas
# Processing Record 4 of Set 6 | kargasok
# Processing Record 5 of Set 6 | carnarvon
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | atafu village
# Processing Record 8 of Set 6 | jalai nur
# Processing Record 9 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | sola
# Processing Record 12 of Set 6 | mendi
# Processing Record 13 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 6 | divrigi
# Processing Record 15 of Set 6 | price
# Processing Record 16 of Set 6 | saint-philippe
# Processing Record 17 of Set 6 | khovd
# Processing Record 18 of Set 6 | bamboo flat
# Processing Record 19 of Set 6 | shenjiamen
# Processing Record 20 of Set 6 | seabra
# Processing Record 21 of Set 6 | changzhou
# Processing Record 22 of Set 6 | tazacorte
# Processing Record 23 of Set 6 | muisne
# Processing Record 24 of Set 6 | jamestown
# Processing Record 25 of Set 6 | kodiak
# Processing Record 26 of Set 6 | tuy hoa
# Processing Record 27 of Set 6 | kasane
# Processing Record 28 of Set 6 | meulaboh
# Processing Record 29 of Set 6 | angaur state
# Processing Record 30 of Set 6 | weno
# Processing Record 31 of Set 6 | tikhvin
# Processing Record 32 of Set 6 | nadi
# Processing Record 33 of Set 6 | essaouira
# Processing Record 34 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 35 of Set 6 | manismata
# Processing Record 36 of Set 6 | humberto de campos
# Processing Record 37 of Set 6 | volosovo
# Processing Record 38 of Set 6 | arraial do cabo
# Processing Record 39 of Set 6 | mount isa
# Processing Record 40 of Set 6 | dwarka
# Processing Record 41 of Set 6 | santarem
# Processing Record 42 of Set 6 | coronel moldes
# Processing Record 43 of Set 6 | daru
# Processing Record 44 of Set 6 | la palma
# Processing Record 45 of Set 6 | lazaro cardenas
# Processing Record 46 of Set 6 | sisimiut
# Processing Record 47 of Set 6 | nar'yan-mar
# Processing Record 48 of Set 6 | boende
# Processing Record 49 of Set 6 | kongolo
# Processing Record 0 of Set 7 | kattivakkam
# Processing Record 1 of Set 7 | goundam
# Processing Record 2 of Set 7 | dickinson
# Processing Record 3 of Set 7 | bukan
# Processing Record 4 of Set 7 | iguape
# Processing Record 5 of Set 7 | nainpur
# Processing Record 6 of Set 7 | razgrad
# Processing Record 7 of Set 7 | sirte
# Processing Record 8 of Set 7 | minas de marcona
# Processing Record 9 of Set 7 | zmeinogorsk
# Processing Record 10 of Set 7 | aldinga beach
# Processing Record 11 of Set 7 | mokhsogollokh
# Processing Record 12 of Set 7 | nosy varika
# Processing Record 13 of Set 7 | fernie
# Processing Record 14 of Set 7 | rijau
# Processing Record 15 of Set 7 | cerro azul
# Processing Record 16 of Set 7 | kingston
# Processing Record 17 of Set 7 | east london
# Processing Record 18 of Set 7 | nantucket
# Processing Record 19 of Set 7 | pimenta bueno
# Processing Record 20 of Set 7 | grants
# Processing Record 21 of Set 7 | arkalyk
# Processing Record 22 of Set 7 | enewetak
# Processing Record 23 of Set 7 | peniche
# Processing Record 24 of Set 7 | joshimath
# Processing Record 25 of Set 7 | porbandar
# Processing Record 26 of Set 7 | farap
# Processing Record 27 of Set 7 | ratnagiri
# Processing Record 28 of Set 7 | reggane
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | bondo
# Processing Record 31 of Set 7 | villa la angostura
# Processing Record 32 of Set 7 | karlovo
# Processing Record 33 of Set 7 | verkhnevilyuysk
# Processing Record 34 of Set 7 | port de pollenca
# Processing Record 35 of Set 7 | saipan
# Processing Record 36 of Set 7 | varna
# Processing Record 37 of Set 7 | nova vicosa
# Processing Record 38 of Set 7 | fallon
# Processing Record 39 of Set 7 | pibor
# City not found. Skipping...
# Processing Record 40 of Set 7 | zhongshu
# Processing Record 41 of Set 7 | la'ie
# Processing Record 42 of Set 7 | minot air force base
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | yahyali
# Processing Record 45 of Set 7 | duck lake
# Processing Record 46 of Set 7 | canico
# Processing Record 47 of Set 7 | astaneh-ye ashrafiyeh
# Processing Record 48 of Set 7 | anloga
# Processing Record 49 of Set 7 | den burg
# Processing Record 0 of Set 8 | frolovo
# Processing Record 1 of Set 8 | juneau
# Processing Record 2 of Set 8 | gumdag
# Processing Record 3 of Set 8 | safaga
# Processing Record 4 of Set 8 | garoowe
# Processing Record 5 of Set 8 | horta
# Processing Record 6 of Set 8 | kurumkan
# Processing Record 7 of Set 8 | taguatinga
# Processing Record 8 of Set 8 | ust'-kulom
# Processing Record 9 of Set 8 | selebi-phikwe
# Processing Record 10 of Set 8 | sandnessjoen
# Processing Record 11 of Set 8 | chumphon
# Processing Record 12 of Set 8 | robertsport
# Processing Record 13 of Set 8 | kapuskasing
# Processing Record 14 of Set 8 | inarajan village
# Processing Record 15 of Set 8 | georgetown
# Processing Record 16 of Set 8 | woolgoolga
# Processing Record 17 of Set 8 | kalmunai
# Processing Record 18 of Set 8 | lubao
# Processing Record 19 of Set 8 | san jose
# Processing Record 20 of Set 8 | tabas
# Processing Record 21 of Set 8 | vanimo
# Processing Record 22 of Set 8 | kunri
# Processing Record 23 of Set 8 | callao
# Processing Record 24 of Set 8 | itoman
# Processing Record 25 of Set 8 | ercis
# Processing Record 26 of Set 8 | rongelap
# Processing Record 27 of Set 8 | flin flon
# Processing Record 28 of Set 8 | zheleznodorozhnyy
# Processing Record 29 of Set 8 | qusmuryn
# Processing Record 30 of Set 8 | chirilagua
# Processing Record 31 of Set 8 | ghadamis
# Processing Record 32 of Set 8 | thurgoona
# Processing Record 33 of Set 8 | masuguru
# Processing Record 34 of Set 8 | palu
# Processing Record 35 of Set 8 | stephenville
# Processing Record 36 of Set 8 | morden
# Processing Record 37 of Set 8 | amble
# Processing Record 38 of Set 8 | antalaha
# Processing Record 39 of Set 8 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 40 of Set 8 | morondava
# Processing Record 41 of Set 8 | prainha
# Processing Record 42 of Set 8 | ruggell
# Processing Record 43 of Set 8 | as suwayrah
# Processing Record 44 of Set 8 | happy valley-goose bay
# Processing Record 45 of Set 8 | tura
# Processing Record 46 of Set 8 | suileng
# Processing Record 47 of Set 8 | singrauli
# Processing Record 48 of Set 8 | sakakah
# Processing Record 49 of Set 8 | polyarnyy
# Processing Record 0 of Set 9 | bodo
# Processing Record 1 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 2 of Set 9 | popondetta
# Processing Record 3 of Set 9 | la ronge
# Processing Record 4 of Set 9 | idri
# Processing Record 5 of Set 9 | kawm umbu
# Processing Record 6 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 9 | sinabang
# Processing Record 8 of Set 9 | mil'kovo
# Processing Record 9 of Set 9 | undurkhaan
# Processing Record 10 of Set 9 | ambon
# Processing Record 11 of Set 9 | bolkhov
# Processing Record 12 of Set 9 | tumaco
# Processing Record 13 of Set 9 | california
# Processing Record 14 of Set 9 | katsuren-haebaru
# Processing Record 15 of Set 9 | ouesso
# Processing Record 16 of Set 9 | salalah
# Processing Record 17 of Set 9 | sovetskiy
# Processing Record 18 of Set 9 | marsabit
# Processing Record 19 of Set 9 | bam
# Processing Record 20 of Set 9 | sargur
# Processing Record 21 of Set 9 | cururupu
# Processing Record 22 of Set 9 | wad az zaki
# Processing Record 23 of Set 9 | brisas de zicatela
# Processing Record 24 of Set 9 | vila franca do campo
# Processing Record 25 of Set 9 | sao joaquim
# Processing Record 26 of Set 9 | cidreira
# Processing Record 27 of Set 9 | laascaanood
# Processing Record 28 of Set 9 | qarqaraly
# Processing Record 29 of Set 9 | port huron
# Processing Record 30 of Set 9 | fort st. john
# Processing Record 31 of Set 9 | kedougou
# Processing Record 32 of Set 9 | chegdomyn
# Processing Record 33 of Set 9 | berdigestyakh
# Processing Record 34 of Set 9 | paros
# Processing Record 35 of Set 9 | puerto lempira
# Processing Record 36 of Set 9 | nadym
# Processing Record 37 of Set 9 | eydhafushi
# Processing Record 38 of Set 9 | batang
# Processing Record 39 of Set 9 | al bawiti
# Processing Record 40 of Set 9 | tsiombe
# Processing Record 41 of Set 9 | tromso
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | tshela
# Processing Record 44 of Set 9 | labrador city
# Processing Record 45 of Set 9 | khandyga
# Processing Record 46 of Set 9 | macomb
# Processing Record 47 of Set 9 | merritt island
# Processing Record 48 of Set 9 | baluntaicun
# City not found. Skipping...
# Processing Record 49 of Set 9 | turbat
# Processing Record 0 of Set 10 | anadyr
# Processing Record 1 of Set 10 | visby
# Processing Record 2 of Set 10 | ta`u
# Processing Record 3 of Set 10 | gamba
# Processing Record 4 of Set 10 | princeton
# Processing Record 5 of Set 10 | mashhad
# Processing Record 6 of Set 10 | mangrol
# Processing Record 7 of Set 10 | yorkton
# Processing Record 8 of Set 10 | yuzhno-kurilsk
# Processing Record 9 of Set 10 | kanniyakumari
# Processing Record 10 of Set 10 | bossangoa
# Processing Record 11 of Set 10 | danville
# Processing Record 12 of Set 10 | rovaniemi
# Processing Record 13 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 14 of Set 10 | bridgewater
# Processing Record 15 of Set 10 | valparaiso
# Processing Record 16 of Set 10 | jaguaruna
# Processing Record 17 of Set 10 | faya-largeau
# Processing Record 18 of Set 10 | arlington
# Processing Record 19 of Set 10 | kremenchuk
# Processing Record 20 of Set 10 | grass valley
# Processing Record 21 of Set 10 | codrington
# Processing Record 22 of Set 10 | semnan
# Processing Record 23 of Set 10 | broken hill
# Processing Record 24 of Set 10 | masterton
# Processing Record 25 of Set 10 | dmitrovsk-orlovskiy
# Processing Record 26 of Set 10 | jolo
# Processing Record 27 of Set 10 | dongkan
# Processing Record 28 of Set 10 | freetown
# Processing Record 29 of Set 10 | cooper's town
# Processing Record 30 of Set 10 | george town
# Processing Record 31 of Set 10 | tifton
# Processing Record 32 of Set 10 | opuwo
# Processing Record 33 of Set 10 | el granada
# Processing Record 34 of Set 10 | moletai
# Processing Record 35 of Set 10 | fort mcmurray
# Processing Record 36 of Set 10 | troitsko-pechorsk
# Processing Record 37 of Set 10 | ust'-ilimsk
# Processing Record 38 of Set 10 | roswell
# Processing Record 39 of Set 10 | port saint john's
# Processing Record 40 of Set 10 | oak hill
# Processing Record 41 of Set 10 | turochak
# Processing Record 42 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 43 of Set 10 | suncho corral
# Processing Record 44 of Set 10 | zalingei
# Processing Record 45 of Set 10 | al aaroui
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | kuanda
# Processing Record 48 of Set 10 | san vicente
# Processing Record 49 of Set 10 | dobryanka
# Processing Record 0 of Set 11 | timbuktu
# Processing Record 1 of Set 11 | cape canaveral
# Processing Record 2 of Set 11 | st ives
# Processing Record 3 of Set 11 | vilyuchinsk
# Processing Record 4 of Set 11 | laojunmiao
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | pontianak
# Processing Record 7 of Set 11 | huamachuco
# Processing Record 8 of Set 11 | muroto-misakicho
# Processing Record 9 of Set 11 | bonthe
# Processing Record 10 of Set 11 | shingu
# Processing Record 11 of Set 11 | liffre
# Processing Record 12 of Set 11 | palmer
# Processing Record 13 of Set 11 | gazojak
# Processing Record 14 of Set 11 | garachico
# Processing Record 15 of Set 11 | caleta de carquin
# Processing Record 16 of Set 11 | mwaya
# Processing Record 17 of Set 11 | camarinas
# Processing Record 18 of Set 11 | barpeta road
# Processing Record 19 of Set 11 | newman
# Processing Record 20 of Set 11 | heyuan
# Processing Record 21 of Set 11 | camocim
# Processing Record 22 of Set 11 | santa cruz
# Processing Record 23 of Set 11 | monte real
# Processing Record 24 of Set 11 | puerto aysen
# Processing Record 25 of Set 11 | ust'-uda
# Processing Record 26 of Set 11 | gemena
# Processing Record 27 of Set 11 | ad dabbah
# Processing Record 28 of Set 11 | midelt
# Processing Record 29 of Set 11 | yantzaza
# Processing Record 30 of Set 11 | pahrump
# Processing Record 31 of Set 11 | mawlaik
# Processing Record 32 of Set 11 | miedzyrzec podlaski
# Processing Record 33 of Set 11 | sosnovoborsk
# Processing Record 34 of Set 11 | impfondo
# Processing Record 35 of Set 11 | jordan
# Processing Record 36 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 37 of Set 11 | minab
# Processing Record 38 of Set 11 | yeppoon city centre
# City not found. Skipping...
# Processing Record 39 of Set 11 | wanning
# Processing Record 40 of Set 11 | sao jose da coroa grande
# Processing Record 41 of Set 11 | manokwari
# Processing Record 42 of Set 11 | presque isle
# Processing Record 43 of Set 11 | pontes e lacerda
# Processing Record 44 of Set 11 | salekhard
# Processing Record 45 of Set 11 | kodinsk
# Processing Record 46 of Set 11 | arno
# Processing Record 47 of Set 11 | chamical
# Processing Record 48 of Set 11 | port macquarie
# Processing Record 49 of Set 11 | toamasina
# Processing Record 0 of Set 12 | peace river
# Processing Record 1 of Set 12 | san ramon
# Processing Record 2 of Set 12 | vernon
# Processing Record 3 of Set 12 | new kingman-butler
# Processing Record 4 of Set 12 | warangal
# Processing Record 5 of Set 12 | tank
# Processing Record 6 of Set 12 | lagoa
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | borogontsy
# Processing Record 9 of Set 12 | sao joao da barra
# Processing Record 10 of Set 12 | kabinda
# Processing Record 11 of Set 12 | quellon
# Processing Record 12 of Set 12 | altai
# Processing Record 13 of Set 12 | camana
# Processing Record 14 of Set 12 | letlhakeng
# Processing Record 15 of Set 12 | trinidad
# Processing Record 16 of Set 12 | leh
# Processing Record 17 of Set 12 | punta del este
# Processing Record 18 of Set 12 | nabire
# Processing Record 19 of Set 12 | kangding
# Processing Record 20 of Set 12 | dali
# Processing Record 21 of Set 12 | fale old settlement
# Processing Record 22 of Set 12 | carauari
# Processing Record 23 of Set 12 | lebowakgomo
# Processing Record 24 of Set 12 | mandra
# Processing Record 25 of Set 12 | belyy yar
# Processing Record 26 of Set 12 | kaseda-shirakame
# Processing Record 27 of Set 12 | midvagur
# Processing Record 28 of Set 12 | santa isabel
# Processing Record 29 of Set 12 | peterhead
# Processing Record 30 of Set 12 | sitka
# Processing Record 31 of Set 12 | gunjur
# Processing Record 32 of Set 12 | walvis bay
# Processing Record 33 of Set 12 | sellersburg
# Processing Record 34 of Set 12 | korla
# Processing Record 35 of Set 12 | schwarzenfeld
# Processing Record 36 of Set 12 | morinville
# Processing Record 37 of Set 12 | zyryanskoye
# Processing Record 38 of Set 12 | labytnangi
# Processing Record 39 of Set 12 | mila doce
# Processing Record 40 of Set 12 | suai
# City not found. Skipping...
# Processing Record 41 of Set 12 | mournies
# Processing Record 42 of Set 12 | brewton
# Processing Record 43 of Set 12 | kapa'a
# Processing Record 44 of Set 12 | severo-yeniseyskiy
# Processing Record 45 of Set 12 | ceelbuur
# Processing Record 46 of Set 12 | fisterra
# Processing Record 47 of Set 12 | lichinga
# Processing Record 48 of Set 12 | gondia
# Processing Record 49 of Set 12 | voskresenskoye
# Processing Record 0 of Set 13 | sambava
# Processing Record 1 of Set 13 | guerrero negro
# Processing Record 2 of Set 13 | annau
# Processing Record 3 of Set 13 | contes
# Processing Record 4 of Set 13 | tucuma
# Processing Record 5 of Set 13 | conde
# Processing Record 6 of Set 13 | ca mau
# Processing Record 7 of Set 13 | repatriacion
# Processing Record 8 of Set 13 | cheyyur
# Processing Record 9 of Set 13 | mili
# Processing Record 10 of Set 13 | pimentel
# Processing Record 11 of Set 13 | ulsteinvik
# Processing Record 12 of Set 13 | mancio lima
# Processing Record 13 of Set 13 | saint-pierre
# Processing Record 14 of Set 13 | maua
# Processing Record 15 of Set 13 | satana
# Processing Record 16 of Set 13 | siguiri
# Processing Record 17 of Set 13 | toropets
# Processing Record 18 of Set 13 | holualoa
# Processing Record 19 of Set 13 | laguna
# Processing Record 20 of Set 13 | powell
# Processing Record 21 of Set 13 | baikunthpur
# Processing Record 22 of Set 13 | ciudad lazaro cardenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          597
# Lat           597
# Lng           597
# Max Temp      597
# Humidity      597
# Cloudiness    597
# Wind Speed    597
# Country       597
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  yellowknife  62.4560 -114.3525    298.44        29          75        7.72
# 1       camiri -20.0500  -63.5167    297.03        35          29        0.00
# 2       luanda  -8.8368   13.2343    294.15        94          20        3.09
# 3        kenai  60.5544 -151.2583    289.20        93         100        5.14
# 4        pisco -13.7000  -76.2167    295.18        60          20        8.75
#
#   Country
# 0      CA
# 1      BO
# 2      AO
# 3      US
# 4      PE

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    277.67        75          93
# 1             punta arenas -53.1500  -70.9167    272.32        79          22
# 2              yellowknife  62.4560 -114.3525    295.14        36          32
# 3                 portland  45.5234 -122.6762    299.47        41          75
# 4                     gizo  -8.1030  156.8419    300.16        86         100
#
#          Wind Speed Country
# City_ID
# 0             15.59      TF
# 1              3.64      CL
# 2              4.74      CA
# 3              4.63      US
# 4              7.81      SB

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature (K)')
plt.title('City Max Latitude vs. Temp')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature (K)')
plt.title('City Latitude vs. Humidity')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs. Cloudiness')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_df = city_data_df.loc[(city_data_df['Lat'] < 0)]
# Display sample data
northern_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        yellowknife  62.4560 -114.3525    295.14        36          32
# 3           portland  45.5234 -122.6762    299.47        41          75
# 6            klyuchi  52.2667   79.1667    295.08        43         100
# 11          la passe  45.5549   -0.8967    292.58        94          18
# 13          thompson  55.7435  -97.8558    285.24        93         100
#
#          Wind Speed Country
# City_ID
# 2              4.74      CA
# 3              4.63      US
# 6              1.68      RU
# 11             2.98      FR
# 13             3.32      CA

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    277.67        75          93
# 1             punta arenas -53.1500  -70.9167    272.32        79          22
# 4                     gizo  -8.1030  156.8419    300.16        86         100
# 5                grytviken -54.2811  -36.5092    273.96        99         100
# 7                  emerald -23.5333  148.1667    295.56        50          86
#
#          Wind Speed Country
# City_ID
# 0             15.59      TF
# 1              3.64      CL
# 4              7.81      SB
# 5              5.24      GS
# 7              7.01      AU

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
#https://www.statology.org/scatterplot-with-regression-line-python/
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)
plt.xlabel('Latitude')
plt.ylabel('Temperature (K)')

#https://git.bootcampcontent.com/Michigan-State-University/MSU-VIRT-DATA-PT-06-2023-U-LOLC/-/blob/main/Class%20Activities%20-%20July%2017th%2C%202023/07-Stu_Weather_Stats/exception_example.ipynb
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(10,280),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.3726550894045969

# %%
# Linear regression on Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(-50,305),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Temperature (K)')


plt.show()
print('there is a stong downward trend in the northern hemisphere and a strong upword trend in the hemisphere')
# Out:
# The r-value is: 0.6638827286883778
# there is a stong downward trend in the northern hemisphere and a strong upword trend in the hemisphere

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
#https://www.statology.org/scatterplot-with-regression-line-python/
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)
plt.xlabel('Latitude')
plt.ylabel('Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(60,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.00214838203097031

# %%
# Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)

plt.xlabel('Latitude')
plt.ylabel('Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(-50,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")


plt.show()
print(' there is very minimal trend in the regression line with the humidity regression line')
# Out:
# The r-value is: 0.0011888285419337794
#  there is very minimal trend in the regression line with the humidity regression line

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
#https://www.statology.org/scatterplot-with-regression-line-python/
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(50,10),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")


plt.show()
# Out:
# The r-value is: 0.0039021331800875862

# %%
# Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(-50,10),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")


plt.show()
print('there is a downward trend is both north and south, more noticable in the south regression line')
# Out:
# The r-value is: 0.018742955642581015
# there is a downward trend is both north and south, more noticable in the south regression line

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(60,10),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")


plt.show()
# Out:
# The r-value is: 0.044288249058986415

# %%
# Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')
plt.plot()
m, b = np.polyfit(x_values, y_values, 1)
plt.plot(x_values, m*x_values+b)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = "y= " + str(round(slope,2)) +"x + " + str(round(intercept,2))
plt.annotate(line,(-30,16),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")



plt.show()
print('there is a slight downward trend in both graph')
# Out:
# The r-value is: 0.042908845041507035
# there is a slight downward trend in both graph

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
